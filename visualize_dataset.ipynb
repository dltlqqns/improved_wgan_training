# %%
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filepath = './data/CUB_200_2011/64images_.pickle'
filepath_crop = './data/CUB_200_2011/64images__crop.pickle'
with open(filepath, 'rb') as f:
    tmp = pickle.load(f)
with open(filepath_crop, 'rb') as f:
    tmp_crop = pickle.load(f)

# %%
idx = 1202
plt.figure()
plt.imshow(tmp['data'][idx])
plt.figure()
plt.imshow(tmp_crop['data'][idx])
